# %% [markdown]
# # First visualization

# %%
import yt
import yt.units as unit
import matplotlib.pyplot as plt
from yt.analysis_modules.halo_analysis.api import *
from yt.visualization.volume_rendering.api import MeshSource
# %matplotlib inline
import numpy as np

# %%
path='/Users/stefany/Desktop/Taller_cosmo/simulacion_gadget_part128_lbox128/gadget_00011/'  #Directory where the data
                                                                                            #files are stored
    
path1='/Users/stefany/Desktop/Taller_cosmo/simulacion_gadget_part128_lbox128/gadget_00001/'

# %% [markdown]
# Proporciona información acerca de la cosmología con la que se realizó la simulación

# %%
fname = path+'part_00011.0'
fname1 = path1+'part_00001.0'

unit_base = {'UnitLength_in_cm'         : 3.08568e+21} #set the units
 #            'UnitMass_in_g'            :   1.989e+43,
  #           'UnitVelocity_in_cm_per_s' :      100000}

#bbox_lim = 1e5 #kpc should encapsulate all the particles in the data set

#bbox = [[-bbox_lim,bbox_lim],
      #  [-bbox_lim,bbox_lim],
       # [-bbox_lim,bbox_lim]]
 
ds = yt.GadgetDataset(fname,unit_base=unit_base) #Read the data set in Gadget format
ds.index           
ad= ds.all_data()   #allows the access to the simulation data

ds1=yt.GadgetDataset(fname1,unit_base=unit_base)
ds1.index           
ad= ds1.all_data()
# Out:
# yt : [INFO     ] 2018-07-31 06:32:07,832 Calculating time from 1.003e+00 to be 4.389e+17 seconds
# yt : [INFO     ] 2018-07-31 06:32:07,903 Parameters: current_time              = 4.388529541106374e+17 s
# yt : [INFO     ] 2018-07-31 06:32:07,905 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2018-07-31 06:32:07,907 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-31 06:32:07,914 Parameters: domain_right_edge         = [127999.99859662 127999.99859662 127999.99859662]
# yt : [INFO     ] 2018-07-31 06:32:07,929 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2018-07-31 06:32:07,941 Parameters: current_redshift          = -0.0031708941294015247
# yt : [INFO     ] 2018-07-31 06:32:07,944 Parameters: omega_lambda              = 0.6947000026702881
# yt : [INFO     ] 2018-07-31 06:32:07,947 Parameters: omega_matter              = 0.3052999973297119
# ...

# %%
p2 = yt.ParticlePlot(ds1,'particle_position_x', 'particle_position_y', 'particle_mass') #Proyection of particle field
                                                                                         #IC

p2.set_axes_unit('Mpc')  #Set the unit for display on the x and y axes of the image.
p2.set_unit('particle_mass', 'Msun/h')
# Out:
# yt : [INFO     ] 2018-07-31 06:32:17,427 xlim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:17,431 ylim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:17,436 xlim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:17,438 ylim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:17,441 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh
# /Users/stefany/miniconda2/envs/yt-env/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p1 = yt.ParticlePlot(ds,'particle_position_x', 'particle_position_y', 'particle_mass') #Proyection of particle field
# Out:
# yt : [INFO     ] 2018-07-31 06:32:27,736 xlim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:27,740 ylim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:27,744 xlim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:27,748 ylim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:32:27,752 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh

# %%
p1.set_axes_unit('Mpc')  #Set the unit for display on the x and y axes of the image.
p1.set_unit('particle_mass', 'Msun/h')
# Out:
# /Users/stefany/miniconda2/envs/yt-env/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
sorted(ds.field_list) # show a list of the available fields
# Out:
# [('Halo', 'Coordinates'),
#  ('Halo', 'Mass'),
#  ('Halo', 'ParticleIDs'),
#  ('Halo', 'Velocities'),
#  ('all', 'Coordinates'),
#  ('all', 'Mass'),
#  ('all', 'ParticleIDs'),
#  ('all', 'Velocities')]

# %%
p = yt.ParticleProjectionPlot(ds,1, 'particle_mass',width=64000, depth=20000) #Make a projection with a 
                                                                               #slice along (0=x, 1=y, 2=z) 
                                                                              #of the x(y or z) axis 
                                                                               #width in the x and y directions
                                                                                # in code units
p.show()
# Out:
# yt : [INFO     ] 2018-07-31 06:32:58,025 xlim = 31999.999298 95999.999298
# yt : [INFO     ] 2018-07-31 06:32:58,031 ylim = 31999.999298 95999.999298
# yt : [INFO     ] 2018-07-31 06:32:58,035 xlim = 31999.999298 95999.999298
# yt : [INFO     ] 2018-07-31 06:32:58,037 ylim = 31999.999298 95999.999298
# yt : [INFO     ] 2018-07-31 06:32:58,041 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh
# /Users/stefany/miniconda2/envs/yt-env/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
ad_data = ds.all_data()

# %% [markdown]
# Information of the particles positions

# %%
print (ad_data['particle_position_x'])
# Out:
# [ 928.20098877 1813.74133301 2625.921875   ...   15.14542198 3275.
#    12.44492245] code_length

# %%
print (ad_data['particle_position_x'].in_units('Mpc'))
# Out:
# [1.37581899 2.68840455 3.8922531  ... 0.02244919 4.85434431 0.01844639] Mpc

# %%
path1='/Users/stefany/Desktop/Taller_cosmo/rockstar_part128_lbox128/output_00011/' #Directory where the data of halos
                                                                                 #are stored
halos  = yt.load(path1+'halos_0.0.bin')
# Out:
# yt : [INFO     ] 2018-07-31 06:33:23,937 Parameters: current_time              = 4.388529541106374e+17 s
# yt : [INFO     ] 2018-07-31 06:33:23,938 Parameters: domain_dimensions         = [2 2 2]
# yt : [INFO     ] 2018-07-31 06:33:23,941 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2018-07-31 06:33:23,943 Parameters: domain_right_edge         = [128. 128. 128.]
# yt : [INFO     ] 2018-07-31 06:33:23,945 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2018-07-31 06:33:23,947 Parameters: current_redshift          = -0.0031708941294015247
# yt : [INFO     ] 2018-07-31 06:33:23,950 Parameters: omega_lambda              = 0.6947000026702881
# yt : [INFO     ] 2018-07-31 06:33:23,951 Parameters: omega_matter              = 0.3052999973297119
# yt : [INFO     ] 2018-07-31 06:33:23,953 Parameters: hubble_constant           = 0.676800012588501

# %%
# Create the halo catalog from this halo list
hc = HaloCatalog(data_ds=ds, halos_ds = halos)
hc.load()
# Out:
# yt : [INFO     ] 2018-07-31 06:33:24,291 Allocating for 3.683e+03 particles (index particle type 'all')
# yt : [INFO     ] 2018-07-31 06:33:24,311 Identified 9.370e+02 octs
# Creating catalog:  97%|█████████▋| 3558/3683 [00:02<00:00, 1753.11it/s]

# %%
ad=hc.halos_ds.all_data()
masses=ad['particle_mass'][:] # Information of the halos
print(min(masses))            
print(len(masses))
# Out:
# 4.978637558580211e+44 g
# 3683

# %%
ad['particle_position_x']
# Out:
# YTArray([1.29609068e+26, 4.90607230e+25, 4.50349033e+25, ...,
#          4.45146433e+26, 3.76724718e+26, 4.38471983e+26]) cm

# %%
p2 = yt.ParticlePlot(ds,'particle_position_x', 'particle_position_y', 'particle_mass')
p2.set_axes_unit('Mpc')
p2.set_unit('particle_mass', 'Msun')
# Out:
# yt : [INFO     ] 2018-07-31 06:33:42,843 xlim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:33:42,845 ylim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:33:42,851 xlim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:33:42,853 ylim = 0.000000 127999.998597
# yt : [INFO     ] 2018-07-31 06:33:42,856 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh
# /Users/stefany/miniconda2/envs/yt-env/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p2.annotate_halos(hc)#,circle_args={'ec':'yellow'})  #Accepts a HaloCatalog and plots
                                                    #a circle at the location of each halo 
                                                    #with the radius of the circle corresponding to the
                                                     #radius of the halo
# Out:
# /Users/stefany/miniconda2/envs/yt-env/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
p.annotate_halos(hc)
# Out:
# /Users/stefany/miniconda2/envs/yt-env/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
print ('left edge: ',ds.domain_left_edge)
print ('right edge: ',ds.domain_right_edge)
print ('center: ',ds.domain_center)
# Out:
# left edge:  [0. 0. 0.] code_length
# right edge:  [127999.99859662 127999.99859662 127999.99859662] code_length
# center:  [63999.99929831 63999.99929831 63999.99929831] code_length

# %%
p.zoom(5)
# Out:
# yt : [INFO     ] 2018-07-31 06:34:14,465 Splatting (('all', 'particle_mass')) onto a 800 by 800 mesh
# /Users/stefany/miniconda2/envs/yt-env/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
for i in sorted(ds.derived_field_list):
  print(i)
# Out:
# ('Halo', 'Coordinates')
# ('Halo', 'Mass')
# ('Halo', 'ParticleIDs')
# ('Halo', 'Velocities')
# ('Halo', 'mesh_id')
# ('Halo', 'particle_angular_momentum')
# ('Halo', 'particle_angular_momentum_magnitude')
# ('Halo', 'particle_angular_momentum_x')
# ('Halo', 'particle_angular_momentum_y')
# ('Halo', 'particle_angular_momentum_z')
# ('Halo', 'particle_cylindrical_velocity_theta')
# ('Halo', 'particle_cylindrical_velocity_z')
# ('Halo', 'particle_index')
# ('Halo', 'particle_mass')
# ('Halo', 'particle_ones')
# ('Halo', 'particle_position')
# ('Halo', 'particle_position_cylindrical_radius')
# ('Halo', 'particle_position_cylindrical_theta')
# ('Halo', 'particle_position_cylindrical_z')
# ('Halo', 'particle_position_relative')
# ('Halo', 'particle_position_relative_x')
# ('Halo', 'particle_position_relative_y')
# ('Halo', 'particle_position_relative_z')
# ('Halo', 'particle_position_spherical_phi')
# ('Halo', 'particle_position_spherical_radius')
# ...

# %%
px = yt.ProjectionPlot(ds, 'x', ('deposit', 'all_density'))
px.show()

# %%
ad2= ds.region(center=center, left_edge=left_edge, right_edge=right_edge)

# %%
print ([tm.in_units('Msun') for tm in ad.quantities.total_mass()])
# Out:
# [0.0 Msun, 5.380273354432809e+16 Msun]

# %%
px1 = yt.ProjectionPlot(ds, 'x', ('deposit', 'all_density'), center=center, width=new_box_size)
px.show()

# %%
px.pan_rel((0.1, 0.0))

# %%
px.zoom(10.0)

# %%
px.zoom(2.0)
px.show()

# %%
px.zoom(10)

# %%
obj = ds.arbitrary_grid([0.0, 0.0, 0.0], [0.99, 0.99, 0.99],
                       dims=[128, 128, 128])

# %%
print(obj["deposit", "all_density"])

# %%
sp = ds.sphere([50, 50, 50], (800, 'kpc'))

# %%
sp = yt.ProjectionPlot(ds, 'x', ('deposit', 'all_density'))
sp.show()
